# %%
import tensorflow as tf
import pandas as pd
import numpy as np

#!pip install tensorflow_decision_forests

import tensorflow_decision_forests as tfdf

# %%
data_test = pd.read_csv('/content/sample_data/california_housing_test.csv')
data_train = pd.read_csv('/content/sample_data/california_housing_train.csv')

data_train.isna().sum()
data_train = data_train.dropna()
data_test = data_test.dropna()
data_train['median_house_value']= data_train['median_house_value'].astype(int)
data_test['median_house_value']= data_test['median_house_value'].astype(int)

# %%
data_train['label'] = pd.cut(x = data_train['median_house_value'], bins = [10000,150000,250000,350000,450000, 600000], labels= [1,2,3, 4, 5])
data_test['label'] = pd.cut(x = data_test['median_house_value'], bins = [10000,150000,250000,350000,450000, 600000], labels= [1,2,3, 4, 5])
data_train = data_train.drop('median_house_value', axis=1)
data_test = data_test.drop('median_house_value', axis=1)

# %%
rslt_df = data_train.loc[data_train['label'].isnull()]
print(rslt_df)
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, label]
# Index: []

# %%
data_train['label'] = pd.to_numeric(data_train['label'], errors='coerce')
data_test['label'] = pd.to_numeric(data_test['label'], errors='coerce')


train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(data_train, label="label")
model = tfdf.keras.RandomForestModel()
model.fit(train_ds)
# Out:
# Use /tmp/tmphhreegba as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:00.352427. Found 17000 examples.
# Training model...
# Model trained in 0:00:24.016828
# Compiling model...
# Model compiled.

# %%
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(data_test, label="label")
model.evaluate(test_ds)
model.summary()
# Out:
# 3/3 [==============================] - 1s 120ms/step - loss: 0.0000e+00
# Model: "random_forest_model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (8):
# 	households
# 	housing_median_age
# 	latitude
# 	longitude
# 	median_income
# 	population
# 	total_bedrooms
# 	total_rooms
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.      "median_income"  0.464106 ################
#     2.           "latitude"  0.294892 ########
#     3.          "longitude"  0.231372 ######
#     4. "housing_median_age"  0.124641 #
#     5.        "total_rooms"  0.101832
#     6.         "population"  0.095293
#     7.         "households"  0.089442
#     8.     "total_bedrooms"  0.089158
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "median_income" 145.000000 ################
#     2.           "latitude" 92.000000 #########
#     3.          "longitude" 33.000000 ###
#     4.        "total_rooms" 25.000000 ##
#     5. "housing_median_age"  5.000000
#
# Variable Importance: NUM_NODES:
#     1.          "longitude" 70000.000000 ################
#     2.           "latitude" 69647.000000 ###############
#     3.      "median_income" 63108.000000 ############
#     4.         "population" 51985.000000 ######
#     5.        "total_rooms" 45381.000000 ##
#     6. "housing_median_age" 44987.000000 ##
#     7.     "total_bedrooms" 41288.000000
#     8.         "households" 40809.000000
#
# Variable Importance: SUM_SCORE:
#     1.      "median_income" 1785788.109979 ################
#     2.          "longitude" 1174698.662943 #########
#     3.           "latitude" 1123584.474694 #########
#     4. "housing_median_age" 370999.840095 #
#     5.         "population" 354057.614056 #
#     6.        "total_rooms" 281791.444131
#     7.     "total_bedrooms" 254567.241668
#     8.         "households" 246315.293616
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.737176 logloss:0.743678
# Number of trees: 300
# Total number of nodes: 854710
#
# Number of nodes by tree:
# Count: 300 Average: 2849.03 StdDev: 136.168
# Min: 2277 Max: 3121 Ignored: 0
# ----------------------------------------------
# [ 2277, 2319)  1   0.33%   0.33%
# [ 2319, 2361)  0   0.00%   0.33%
# [ 2361, 2403)  0   0.00%   0.33%
# [ 2403, 2446)  1   0.33%   0.67%
# [ 2446, 2488)  2   0.67%   1.33%
# [ 2488, 2530)  1   0.33%   1.67%
# [ 2530, 2572)  6   2.00%   3.67% #
# [ 2572, 2615)  6   2.00%   5.67% #
# [ 2615, 2657) 14   4.67%  10.33% ###
# [ 2657, 2699) 12   4.00%  14.33% ###
# [ 2699, 2741) 15   5.00%  19.33% ###
# [ 2741, 2784) 23   7.67%  27.00% #####
# [ 2784, 2826) 31  10.33%  37.33% #######
# [ 2826, 2868) 37  12.33%  49.67% #########
# [ 2868, 2910) 43  14.33%  64.00% ##########
# [ 2910, 2953) 37  12.33%  76.33% #########
# [ 2953, 2995) 32  10.67%  87.00% #######
# [ 2995, 3037) 27   9.00%  96.00% ######
# [ 3037, 3079)  7   2.33%  98.33% ##
# [ 3079, 3121]  5   1.67% 100.00% #
#
# Depth by leafs:
# Count: 427505 Average: 12.3351 StdDev: 2.12759
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)    12   0.00%   0.00%
# [  4,  5)   107   0.03%   0.03%
# [  5,  6)   615   0.14%   0.17%
# [  6,  7)  2041   0.48%   0.65%
# [  7,  8)  5526   1.29%   1.94% #
# [  8,  9) 13123   3.07%   5.01% ##
# [  9, 10) 24928   5.83%  10.84% ###
# [ 10, 11) 39942   9.34%  20.19% #####
# [ 11, 12) 55827  13.06%  33.24% #######
# [ 12, 13) 66569  15.57%  48.82% ########
# [ 13, 14) 69781  16.32%  65.14% ########
# [ 14, 15) 65482  15.32%  80.46% ########
# [ 15, 15] 83552  19.54% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 427505 Average: 11.9297 StdDev: 21.7078
# Min: 5 Max: 844 Ignored: 0
# ----------------------------------------------
# [   5,  47) 414347  96.92%  96.92% ##########
# [  47,  89)   8585   2.01%  98.93%
# [  89, 131)   2344   0.55%  99.48%
# [ 131, 173)    941   0.22%  99.70%
# [ 173, 215)    459   0.11%  99.81%
# [ 215, 257)    245   0.06%  99.86%
# [ 257, 299)    162   0.04%  99.90%
# [ 299, 341)    120   0.03%  99.93%
# [ 341, 383)     74   0.02%  99.95%
# [ 383, 425)     47   0.01%  99.96%
# [ 425, 467)     42   0.01%  99.97%
# [ 467, 509)     40   0.01%  99.98%
# [ 509, 551)     32   0.01%  99.98%
# [ 551, 593)     29   0.01%  99.99%
# [ 593, 635)      6   0.00%  99.99%
# [ 635, 677)     11   0.00% 100.00%
# [ 677, 719)     14   0.00% 100.00%
# [ 719, 761)      3   0.00% 100.00%
# [ 761, 803)      0   0.00% 100.00%
# [ 803, 844]      4   0.00% 100.00%
#
# Attribute in nodes:
# 	70000 : longitude [NUMERICAL]
# 	69647 : latitude [NUMERICAL]
# 	63108 : median_income [NUMERICAL]
# 	51985 : population [NUMERICAL]
# 	45381 : total_rooms [NUMERICAL]
# 	44987 : housing_median_age [NUMERICAL]
# 	41288 : total_bedrooms [NUMERICAL]
# 	40809 : households [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	145 : median_income [NUMERICAL]
# 	92 : latitude [NUMERICAL]
# 	33 : longitude [NUMERICAL]
# 	25 : total_rooms [NUMERICAL]
# 	5 : housing_median_age [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	448 : median_income [NUMERICAL]
# 	232 : latitude [NUMERICAL]
# 	118 : longitude [NUMERICAL]
# 	48 : housing_median_age [NUMERICAL]
# 	45 : total_rooms [NUMERICAL]
# 	9 : population [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	910 : median_income [NUMERICAL]
# 	504 : latitude [NUMERICAL]
# 	385 : longitude [NUMERICAL]
# 	166 : housing_median_age [NUMERICAL]
# 	63 : total_rooms [NUMERICAL]
# 	28 : households [NUMERICAL]
# 	24 : population [NUMERICAL]
# 	20 : total_bedrooms [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1644 : median_income [NUMERICAL]
# 	1024 : latitude [NUMERICAL]
# 	984 : longitude [NUMERICAL]
# 	422 : housing_median_age [NUMERICAL]
# 	127 : total_rooms [NUMERICAL]
# 	98 : households [NUMERICAL]
# 	97 : population [NUMERICAL]
# 	92 : total_bedrooms [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	4463 : median_income [NUMERICAL]
# 	4227 : longitude [NUMERICAL]
# 	4004 : latitude [NUMERICAL]
# 	1746 : housing_median_age [NUMERICAL]
# 	967 : population [NUMERICAL]
# 	835 : total_bedrooms [NUMERICAL]
# 	827 : total_rooms [NUMERICAL]
# 	811 : households [NUMERICAL]
#
# Condition type in nodes:
# 	427205 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4488 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	17880 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.659465 logloss:12.2741
# 	trees: 11, Out-of-bag evaluation: accuracy:0.69086 logloss:5.0681
# 	trees: 21, Out-of-bag evaluation: accuracy:0.711159 logloss:2.90299
# 	trees: 31, Out-of-bag evaluation: accuracy:0.722647 logloss:2.09537
# 	trees: 41, Out-of-bag evaluation: accuracy:0.724588 logloss:1.70541
# 	trees: 51, Out-of-bag evaluation: accuracy:0.729059 logloss:1.49808
# 	trees: 61, Out-of-bag evaluation: accuracy:0.730059 logloss:1.32673
# 	trees: 71, Out-of-bag evaluation: accuracy:0.729882 logloss:1.20896
# 	trees: 81, Out-of-bag evaluation: accuracy:0.732588 logloss:1.1345
# 	trees: 91, Out-of-bag evaluation: accuracy:0.733941 logloss:1.06687
# 	trees: 101, Out-of-bag evaluation: accuracy:0.734588 logloss:1.01871
# 	trees: 111, Out-of-bag evaluation: accuracy:0.736353 logloss:0.981039
# 	trees: 121, Out-of-bag evaluation: accuracy:0.735 logloss:0.954354
# 	trees: 131, Out-of-bag evaluation: accuracy:0.736235 logloss:0.930274
# 	trees: 141, Out-of-bag evaluation: accuracy:0.737588 logloss:0.893876
# 	trees: 151, Out-of-bag evaluation: accuracy:0.737706 logloss:0.872122
# 	trees: 161, Out-of-bag evaluation: accuracy:0.738824 logloss:0.850602
# 	trees: 171, Out-of-bag evaluation: accuracy:0.738824 logloss:0.834219
# 	trees: 181, Out-of-bag evaluation: accuracy:0.738412 logloss:0.822662
# 	trees: 191, Out-of-bag evaluation: accuracy:0.738 logloss:0.817095
# 	trees: 201, Out-of-bag evaluation: accuracy:0.737765 logloss:0.801291
# 	trees: 211, Out-of-bag evaluation: accuracy:0.737 logloss:0.792641
# 	trees: 221, Out-of-bag evaluation: accuracy:0.737118 logloss:0.783174
# 	trees: 231, Out-of-bag evaluation: accuracy:0.737412 logloss:0.781055
# 	trees: 241, Out-of-bag evaluation: accuracy:0.736353 logloss:0.769799
# 	trees: 251, Out-of-bag evaluation: accuracy:0.737 logloss:0.764073
# 	trees: 261, Out-of-bag evaluation: accuracy:0.736588 logloss:0.759788
# 	trees: 271, Out-of-bag evaluation: accuracy:0.737176 logloss:0.755948
# 	trees: 281, Out-of-bag evaluation: accuracy:0.737118 logloss:0.751796
# 	trees: 291, Out-of-bag evaluation: accuracy:0.737 logloss:0.745889
# 	trees: 300, Out-of-bag evaluation: accuracy:0.737176 logloss:0.743678
